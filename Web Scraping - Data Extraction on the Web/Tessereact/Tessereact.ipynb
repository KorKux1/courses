# %% [markdown]
# # OCR con Tesseract
# En esta clase veremos algunos ejemplos de utilización de Tesseract-OCR, una biblioteca creada por HP (y actualmente mantenida por Google) para realizar reconocimiento óptico de caracteres.
#
# Importamos las bibliotecas que vamos a usar en la clase

# %%
import tesserocr # Para hacer OCR
import numpy as np # Para hacer manipulación básica de imágenes
import matplotlib.pyplot as plt # Para visualizar imágenes
from PIL import Image , ImageOps# Para cambiar el formato de archivos
# %matplotlib inline

# %%
long_text = plt.imread('texto_largo.png')
plt.figure(figsize=(15,5))
plt.imshow(long_text)
plt.axis(False);

# %%
type(text_orc)
# Out:
# str

# %%
text_orc = tesserocr.file_to_text('texto_largo.png', lang='spa')

# %%
print(text_orc)
# Out:
# Este texto es una prueba.
#
# En muchas oportunidades encontraremos textos en PDF o imágenes
# que contengan texto y será de utilidad poder procesarlas como
# cadenas de caracteres en lugar de como inágenes. Aquí es donde
# el reconocimiento óptico de caracteres nos será de ayuda.

# %%
img = plt.imread('imagen de prueba.png')
plt.imshow(img)

# %%
ocr_text = tesserocr.file_to_text('imagen de prueba.png', lang='spa')

# %%
print(ocr_text)
# Out:
# ¡Hola! Este texto es un
# ejemplo para el curso de
# Web scraping de Platzi.

# %% [markdown]
# En ocasiones la libreria no reconoce los caracteres por los fondos oscuros, la letra o otras cuestiones. Por lo que lo mejor es tratarlas

# %%
img = plt.imread('reto1.jpeg')
plt.imshow(img)

# %%
img.shape
# Out:
# (600, 480, 3)

# %%
img_rgb[0,0,0]
# Out:
# 238

# %% [markdown]
# El valor del pixel puede cenir entre 0 y 1 o de 0 a 255. Dependiendo de la códificación

# %%
image = Image.open('reto1.jpeg')
inverted_image = ImageOps.invert(image)
inverted_image.save('challenge_1_inverted.jpeg')

# %%
plt.imshow(inverted_image)

# %%
img_inv = plt.imread('challenge_1_inverted.jpeg')

# %%
img_rg = img_inv.mean(axis=2)

# %%
plt.imshow(img_rg, cmap='Greys_r')

# %%
img_pil = Image.fromarray(np.uint8(img_rg))

# %%
type(img_pil)
# Out:
# PIL.Image.Image

# %%
img_pil_inv = Image.fromarray(np.uint8(img_inv))

# %%
print(tesserocr.image_to_text(img_pil_inv, lang='spa'))
# Para estos casos es mejor útilizar bibliotecas más avanzadas como open CV
