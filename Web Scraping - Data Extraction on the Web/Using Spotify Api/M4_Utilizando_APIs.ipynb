# %% [markdown]
# # Módulo 4: APIs
# ## Spotify
#
# ![Imagen Spotify](https://developer.spotify.com/assets/branding-guidelines/logo@2x.png)
#
# En este módulo utilizaremos APIs para obtener información sobre artistas, discos y tracks disponibles en Spotify. Pero primero.. ¿Qué es una API?
# Por sus siglas en inglés, una API es una interfaz para programar aplicaciones (Application Programming Interface). Es decir que es un conjunto de funciones, métodos, reglas y definiciones que nos permitirán desarrollar aplicaciones (en este caso un scraper) que se comuniquen con los servidores de Spotify. Las APIs son diseñadas y desarrolladas por las empresas que tienen interés en que se desarrollen aplicaciones (públicas o privadas) que utilicen sus servicios. Spotify tiene APIs públicas y bien documentadas que estaremos usando en el desarrollo de este proyecto.
#
# ## REST
# Un término se seguramente te vas a encontrar cuando estés buscando información en internet es REST o RESTful. Significa representational state transfer y si una API es REST o RESTful, implica que respeta unos determinados principios de arquitectura, como por ejemplo un protocolo de comunicación cliente/servidor (que será HTTP) y (entre otras cosas) un conjunto de operaciones definidas que conocemos como métodos. Ya veníamos usando el método GET para hacer solicitudes a servidores web.
#
# ## Documentación
# Como mencioné antes, las APIs son diseñadas por las mismas empresas que tienen interés en que se desarrollen aplicaciones (públicas o privadas) que consuman sus servicios o información. Es por eso que la forma de utilizar las APIs variará dependiendo del servicio que querramos consumir. No es lo mismo utilizar las APIs de Spotify que las APIs de Twitter. Por esta razón es de suma importancia leer la documentación disponible, generalmente en la sección de desarrolladores de cada sitio. Te dejo el link a la de Spotify
#
# ## JSON
# Json significa JavaScript Object Notation y es un formato para describir objetos que ganó tanta popularidad en su uso que ahora se lo considera independiente del lenguaje. De hecho, lo utilizaremos en este proyecto por más que estemos trabajando en Python, porque es la forma en la que obtendremos las respuestas a las solicitudes que realicemos utilizando las APIs. Para nosotros, no será ni más ni menos que un diccionario con algunas particularidades que iremos viendo a lo largo del curso.
#
# Links útiles para la clase:
#
# * [Documentación de Spotify - Artistas](https://developer.spotify.com/documentation/web-api/reference/artists/)
# * [Iron Maiden en Spotify](https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao)
# * [Registrá tu aplicación](https://developer.spotify.com/documentation/general/guides/app-settings/#register-your-app)

# %%
base_url = 'https://api.spotify.com/v1'

# %%
endpoint_artist = '/artists/{artist_id}'
id_artist = '4z2t6LMcloTFkHCFSbJqO7'

# %%
url = base_url + endpoint_artist.format(artist_id=id_artist)
url
# Out:
# 'https://api.spotify.com/v1/artists/4z2t6LMcloTFkHCFSbJqO7'

# %%
import requests

# %%
request = requests.get(url)

# %%
# El 401 nos indica que no estamos autorizados para acceder a ese recurso
request.status_code
# Out:
# 401

# %%
request.json()
# Out:
# {'error': {'message': 'No token provided', 'status': 401}}

# %%
token_url = 'https://accounts.spotify.com/api/token'

# %%
params = {'grant_type': 'client_credentials'}

# %%
client_id = input('client_id ')

# %%
client_secret = input('client_secret ')# Nunca compartirlo

# %%
import base64

# %%
client_str = '{client_id}:{client_secret}'.format(client_id=client_id, client_secret=client_secret)
client_encode = base64.b64encode(client_str.encode("utf-8"))  # Codificado en Bytes
client_encode = str(client_encode, "utf-8")  # Codificado en String

# %%
headers = {'Authorization': f'Basic {client_encode}'}

# %%
request = requests.post(token_url, data=params, headers=headers)

# %%
request
# Out:
# <Response [200]>

# %%
request.json()

# %%
token = request.json()['access_token']
token

# %%
header = {'Authorization': f'Bearer {token}'}
request = requests.get(url, headers=header)

# %%
request.status_code
# Out:
# 200

# %%
request.json()
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/4z2t6LMcloTFkHCFSbJqO7'},
#  'followers': {'href': None, 'total': 62515},
#  'genres': ['rap conciencia'],
#  'href': 'https://api.spotify.com/v1/artists/4z2t6LMcloTFkHCFSbJqO7',
#  'id': '4z2t6LMcloTFkHCFSbJqO7',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/d29b5adc9192d449a1aa033f8d3fad09442863ae',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/563ba19da17be9765e4b81479b1806f9a045811b',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/abf5b958aab1f4d3a059aeddf72a8c42a86abaf8',
#    'width': 160}],
#  'name': 'Green A',
#  'popularity': 48,
#  'type': 'artist',
#  'uri': 'spotify:artist:4z2t6LMcloTFkHCFSbJqO7'}

# %%
search_url = 'https://api.spotify.com/v1/search'

# %%
search_params = {'q':'Green+A', 'type':'artist', 'market':'CO'}

# %%
search = requests.get(search_url, headers=header, params=search_params)

# %%
search.status_code
# Out:
# 200

# %%
search.json()

# %%
import pandas as pd

# %%
df = pd.DataFrame(search.json()['artists']['items'])
df.head()
# Out:
#                                        external_urls  ...                                    uri
# 0  {'spotify': 'https://open.spotify.com/artist/4...  ...  spotify:artist:4z2t6LMcloTFkHCFSbJqO7
# 1  {'spotify': 'https://open.spotify.com/artist/0...  ...  spotify:artist:0q1c8JReFMy4igMuTUc6Sd
# 2  {'spotify': 'https://open.spotify.com/artist/6...  ...  spotify:artist:64FwB76hSP9VtYtPSBbEY7
# 3  {'spotify': 'https://open.spotify.com/artist/2...  ...  spotify:artist:2bITUcKcwLGMkmFIKQR00t
# 4  {'spotify': 'https://open.spotify.com/artist/4...  ...  spotify:artist:4QvgGvpgzgyUOo8Yp8LDm9
#
# [5 rows x 10 columns]

# %%
df.iloc[0]
# Out:
# external_urls    {'spotify': 'https://open.spotify.com/artist/4...
# followers                           {'href': None, 'total': 62515}
# genres                                            [rap conciencia]
# href             https://api.spotify.com/v1/artists/4z2t6LMcloT...
# id                                          4z2t6LMcloTFkHCFSbJqO7
# images           [{'height': 640, 'url': 'https://i.scdn.co/ima...
# name                                                       Green A
# popularity                                                      48
# type                                                        artist
# uri                          spotify:artist:4z2t6LMcloTFkHCFSbJqO7
# Name: 0, dtype: object

# %%
def get_token(client_id, client_secret):
  encoded = base64.b64encode(bytes(client_id+':'+client_secret, 'utf-8'))
  params = {'grant_type':'client_credentials'}
  header = {'Authorization': f'Basic {str(encoded, "utf-8")}'}
  r = requests.post('https://accounts.spotify.com/api/token', headers=header, data=params)
  if r.status_code == 200:
    print(f'Token valido por {r.json()["expires_in"]} segundos')
    return r.json()['access_token']
  else:
    print(f'Error en la request: {r.json()}')
    return None

# %%
token = get_token(client_id, client_secret)
# Out:
# Token valido por 3600 segundos

# %%
header = {'Authorization': f'Bearer {token}'}

# %%
endpoint_albums = endpoint_artist+'/albums'
endpoint_albums
# Out:
# '/artists/{artist_id}/albums'

# %%
albums_url = base_url+endpoint_albums
albums_url
# Out:
# 'https://api.spotify.com/v1/artists/{artist_id}/albums'

# %%
params = {'country': 'CO'}

# %%
albums = requests.get(albums_url.format(artist_id=id_artist), headers=header, params=params)

# %%
albums.status_code
# Out:
# 200

# %%
albums.json()['items'][0]
# Out:
# {'album_group': 'single',
#  'album_type': 'single',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4z2t6LMcloTFkHCFSbJqO7'},
#    'href': 'https://api.spotify.com/v1/artists/4z2t6LMcloTFkHCFSbJqO7',
#    'id': '4z2t6LMcloTFkHCFSbJqO7',
#    'name': 'Green A',
#    'type': 'artist',
#    'uri': 'spotify:artist:4z2t6LMcloTFkHCFSbJqO7'}],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/0PSn4BklmUWXpVYFZ0d97x'},
#  'href': 'https://api.spotify.com/v1/albums/0PSn4BklmUWXpVYFZ0d97x',
#  'id': '0PSn4BklmUWXpVYFZ0d97x',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b2730a6fe7556daa6d2a997edf5c',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e020a6fe7556daa6d2a997edf5c',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d000048510a6fe7556daa6d2a997edf5c',
#    'width': 64}],
#  'name': 'Descontrólate (Qué vacilón)',
#  'release_date': '2020-01-22',
#  'release_date_precision': 'day',
#  'total_tracks': 1,
#  'type': 'album',
#  'uri': 'spotify:album:0PSn4BklmUWXpVYFZ0d97x'}

# %%
albums_list = [ (album['id'], album['name']) for album in albums.json()['items']]
albums_list
# Out:
# [('0PSn4BklmUWXpVYFZ0d97x', 'Descontrólate (Qué vacilón)'),
#  ('3HPzhzK8ifYs0XaXs9mcZb', 'Confesión de un asesino'),
#  ('7baIFhe5yFUrucH8Ak05Sw', 'Indiferente (Trastornos Mentales)'),
#  ('26DQoCqd2pOR5tp8kh5Ohq', 'Carta de Amor (Trastornos Mentales)'),
#  ('79Ab47V6uqM9DMUBk5OPII', 'Acosador (Trastornos Mentales)'),
#  ('6wKBkjHTTgCpImy6dfzs2l', 'Paranoide (Trastornos Mentales)'),
#  ('29weg5AeH5PHs2ZYD5K2iD', 'Odio Amarte (Trastornos Mentales)'),
#  ('28Opulva19LhGeUtamDCe7', 'El Verdugo de Dios (Trastornos Mentales)'),
#  ('2DtONNe81cTsXKE74tHgnU', 'Si pudiera volver a soñar'),
#  ('4uQMu0Aly9HDGQ47hO0P5l', 'Exorcismo (Trastornos Mentales)'),
#  ('5aAAxytqVY8d585zZ1DlFP', 'Depresión'),
#  ('3vydQ7g68cmZQbROf6w8Wm', 'Vicio a la tentación'),
#  ('3d8bQlbg5chL6KyvkJPacA', 'Personalidad Múltiple'),
#  ('1SqeY2hs7DPNv9FlmFXNEn', 'Mis Viejos Amigos (Remastered)'),
#  ('1BEWfGNeYTCCfsS4EsIAyI', 'Dentro de Mi Cabeza'),
#  ('7sGor9Wkc2lHq0JoqYq8Qb', 'Baby'),
#  ('72DaGbhqg4Pre4FURCSADF', 'El Diablo Verde'),
#  ('59bYwDHm7k9RbRwr5uxqr8', 'El Miedo'),
#  ('1M3644rbk8fIEVQCA6DIfA', 'Después de la muerte'),
#  ('1IpxplrYzJ2bW6KCg9LwOk', 'Perdido (Remasterizada)')]

# %%
endpoint_album = '/albums/{album_id}'
album_params = {'market':'CO'}

# %%
verdugo_de_dios_id = '28Opulva19LhGeUtamDCe7'

# %%
verdugo_de_dios = requests.get(base_url+endpoint_album.format(album_id=verdugo_de_dios_id)+'/tracks', headers=header, params=params)
verdugo_de_dios
# Out:
# <Response [200]>

# %%
verdugo_de_dios.json()['items']
# Out:
# [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4z2t6LMcloTFkHCFSbJqO7'},
#     'href': 'https://api.spotify.com/v1/artists/4z2t6LMcloTFkHCFSbJqO7',
#     'id': '4z2t6LMcloTFkHCFSbJqO7',
#     'name': 'Green A',
#     'type': 'artist',
#     'uri': 'spotify:artist:4z2t6LMcloTFkHCFSbJqO7'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 263588,
#   'explicit': True,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0uLcqDvinPwtDodcJd8BNs'},
#   'href': 'https://api.spotify.com/v1/tracks/0uLcqDvinPwtDodcJd8BNs',
#   'id': '0uLcqDvinPwtDodcJd8BNs',
#   'is_local': False,
#   'name': 'El Verdugo de Dios (Trastornos Mentales)',
#   'preview_url': 'https://p.scdn.co/mp3-preview/19f246884cb9470179c21d9fbdbcf1047ce2a3b2?cid=47edb8490fbe4f26b7d4023e86d43773',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:0uLcqDvinPwtDodcJd8BNs'}]

# %%
[ (track['id'], track['name']) for track in verdugo_de_dios.json()['items']]
# Out:
# [('0uLcqDvinPwtDodcJd8BNs', 'El Verdugo de Dios (Trastornos Mentales)')]

# %%
def get_discography(artist_id, token, return_name=False, page_limit=50, country=None):
  url = f'https://api.spotify.com/v1/artists/{artist_id}/albums'
  header = {'Authorization': f'Bearer {token}'}
  params = {'limit': page_limit, 
            'offset': 0,
            'country': country}
  albums_list = []
  r = requests.get(url, params=params, headers=header)

  if r.status_code != 200:
    print(f'Error en la request {r.json}')
    return None
  
  if return_name:
    albums_list += [ (item['id'], item['name']) for item in r.json()['items']]
  else: 
    albums_list += [ item['id'] for item in r.json()['items']]

  while (r.json()['next']):
    r = requests.get(r.json()['next'], headers=header)

    if r.status_code != 200:
      print(f'Error en la request {r.json}')
      continue
    
    if return_name:
      albums_list += [ (item['id'], item['name']) for item in r.json()['items']]
    else: 
      albums_list += [ item['id'] for item in r.json()['items']]
  return  albums_list

# %%
def get_tracks(album_id, token, return_name=False, page_limit=50, market=None):
  url = f'https://api.spotify.com/v1/albums/{album_id}/tracks'
  header = {'Authorization': f'Bearer {token}'}
  params = {'limit': page_limit, 
            'offset': 0,
            'market': market}
  tracks_list = []
  r = requests.get(url, params=params, headers=header)

  if r.status_code != 200:
    print('Error en request.', r.json())
    return None

  if return_name:
    tracks_list += [(item['id'], item['name']) for item in r.json()['items']]
  else:
    tracks_list += [item['id'] for item in r.json()['items']]

  while r.json()['next']:
    r = requests.get(r.json()['next'], headers=header)

    if r.status_code != 200:
      print('Error en request.', r.json())
      continue

    if return_name:
      tracks_list += [(item['id'], item['name']) for item in r.json()['items']]
    else:
      tracks_list += [item['id'] for item in r.json()['items']]
  
  return tracks_list

# %% [markdown]
# Utilizando estas funciones podemos obtener todos las canciones que tiene un artista publicadas en Spotify

# %%
def print_all_song_artist(id_artist, token):
  for album in get_discography(id_artist, token, return_name=True, country='CO'):
    print(f'{album[1]}:')
    for track in get_tracks(album[0], token, return_name=True, market='CO'):
      print(f'\t {track[1]}')

# %%
print_all_song_artist(id_artist, token)
# Out:
# Descontrólate (Qué vacilón):
# 	 Descontrólate (Qué vacilón)
# Confesión de un asesino:
# 	 Confesión de un asesino
# Indiferente (Trastornos Mentales):
# 	 Indiferente (Trastornos Mentales)
# Carta de Amor (Trastornos Mentales):
# 	 Carta de Amor (Trastornos Mentales)
# Acosador (Trastornos Mentales):
# 	 Acosador (Trastornos Mentales)
# Paranoide (Trastornos Mentales):
# 	 Paranoide (Trastornos Mentales)
# Odio Amarte (Trastornos Mentales):
# 	 Odio Amarte (Trastornos Mentales)
# El Verdugo de Dios (Trastornos Mentales):
# 	 El Verdugo de Dios (Trastornos Mentales)
# Si pudiera volver a soñar:
# 	 Si pudiera volver a soñar
# Exorcismo (Trastornos Mentales):
# 	 Exorcismo (Trastornos Mentales)
# Depresión:
# 	 Depresión
# Vicio a la tentación:
# 	 Vicio a la tentación
# Personalidad Múltiple:
# 	 Personalidad Múltiple
# Mis Viejos Amigos (Remastered):
# 	 Mis Viejos Amigos - Remastered
# Dentro de Mi Cabeza:
# 	 Dentro de Mi Cabeza
# Baby:
# 	 Baby
# El Diablo Verde:
# 	 El Diablo Verde
# El Miedo:
# 	 El Miedo
# Después de la muerte:
# 	 Después de la muerte
# Perdido (Remasterizada):
# 	 Perdido (Remasterizada)
# El Fracaso:
# 	 El Fracaso
# A Pesar de Todo:
# 	 A Pesar de Todo
# Invencible:
# 	 Invencible
# Nadie Sabe:
# 	 Nadie Sabe
# Nada:
# 	 Nada
# Tengo la Magia:
# 	 Tengo la Magia
# Tragedia de Amor:
# 	 Tragedia de Amor
# Mil Demonios:
# 	 Mil Demonios
# Si tan sólo supieran:
# 	 Si tan sólo supieran
# Exorcismo:
# 	 Exorcismo
# Estoy Loco:
# 	 Estoy Loco
# Acosador:
# 	 Acosador
# Triste Carnaval:
# 	 Triste Carnaval
# Mi evolución:
# 	 Mi evolución
# Loco Por Ti:
# 	 Loco Por Ti
# Veneno escéptico:
# 	 Veneno escéptico
# Paranoide:
# 	 Paranoide
# Carta a Dios:
# 	 Carta a Dios
# Hubo Una Vez:
# 	 Hubo Una Vez
# Sólo una vida:
# 	 Sólo una vida
# Esta Droga Es Especial:
# 	 Esta Droga Es Especial
# Asesinos de la Creatividad:
# 	 Asesinos de la Creatividad
# Mundo Hipócrita:
# 	 Mundo Hipócrita
# Analogía de una sociedad que no sueña:
# 	 Analogía de una sociedad que no sueña
# Perspectiva Cambiante:
# 	 Perspectiva Cambiante
# El Diablo Cuenta Su Historia:
# 	 El Diablo Cuenta Su Historia
# Porque Cuente:
# 	 Porque Cuente
# 	 Estoy Aquí
# 	 La Elección
# 	 Cicatrices
# 	 El Valor de un Amigo
# 	 La Purga
# 	 Nunca Más Dormirás
# 	 Parte de Mi
# 	 Después de Tanto
# 	 Némesis
# 	 Uno de los Nuestros
# La Elección:
# 	 La Elección
# 	 La Elección - Instrumental

# %%
id_santaflow = '3uvTa6pDzj0T6EfMslXOCs'
print_all_song_artist(id_santaflow, token)
# Out:
# Nacido para Ganar:
# 	 Nacido para Ganar
# 	 Presagio - Titán Remix
# 	 Pienso en Rap - Remix
# 	 Óyeme Entiéndeme - Remix
# 	 Hardcore Español
# 	 Marionetas
# 	 Moral de Carcamal
# 	 Devórame Esta Noche
# 	 Noches Frías
# 	 Un Cielo Común
# 	 Historia de un Tenedor
# 	 Tu Inspiración
# 	 La Misma Canción
# 	 Toma Asiento
# 	 La Industria Musical
# 	 Santaclown
# 	 Nacido para Ganar - Remíx
# Red Vol.3: Las Cenizas del Apocalipsis:
# 	 Nana al Decadente
# 	 No Hay 2 Sin 3
# 	 La Resistencia
# 	 Menuda Fiesta
# 	 Tu Voluntad
# 	 Tóxico Destino
# 	 Méritos Propios
# 	 Brusgüein
# 	 Nana al Decadente - Instrumental
# 	 No Hay 2 Sin 3 - Instrumental
# 	 La Resistencia - Instrumental
# 	 Menuda Fiesta - Instrumental
# 	 Tu Voluntad - Instrumental
# 	 Tóxico Destino - Instrumental
# 	 Méritos Propios - Instrumental
# 	 Brusgüein - Instrumental
# Magnos Team:
# 	 Prólogo
# 	 Bang Bang
# 	 Antihéroes
# 	 Roast Yourself
# 	 A Nuestra Merced
# 	 Feminazis
# 	 Mala Suerte
# 	 Guardianes de la Moral
# Red Vol.2: Las Llamas de la Verdad:
# 	 Las Llamas de la Verdad
# 	 Tu Sabor
# 	 Tanto Que Aprender
# 	 Guerra de Clanes
# 	 Sin Tregua
# 	 Mierda en Hd
# 	 Las Llamas de la Verdad - Instrumental
# 	 Tu Sabor - Instrumental
# 	 Tanto Que Aprender - Instrumental
# 	 Guerra de Clanes - Instrumental
# 	 Sin Tregua - Instrumental
# 	 Mierda en Hd - Instrumental
# Red Vol.1 Deluxe:
# 	 Red
# 	 Espabila
# 	 Mi Candidatura
# 	 Nadie Es de Nadie
# 	 Tiempo de Lucha
# 	 Sin Miedo a Caer
# 	 Las Cartas Sobre la Mesa
# 	 Next Level - Remix
# 	 El Secreto - Remix
# 	 Sin Miedo a Caer (Remix)
# Red Vol.1: El Retorno del Fénix:
# 	 Red
# 	 Espabila
# 	 Mi Candidatura
# 	 Nadie Es de Nadie
# 	 Tiempo de Lucha
# 	 Sin Miedo a Caer
# 	 Las Cartas Sobre la Mesa
# 	 Red - Instrumental Version
# 	 Espabila - Instrumental Version
# 	 Mi Candidatura - Instrumental Version
# 	 Nadie Es de Nadie - Instrumental Version
# 	 Tiempo de Lucha - Instrumental Version
# 	 Sin Miedo a Caer - Instrumental Version
# 	 Las Cartas Sobre la Mesa - Instrumental Version
# Atlántico: Intrumentales:
# 	 Un Día Especial - Instrumental
# 	 Sigo Vivo - Instrumental
# 	 El Túnel - Instrumental
# 	 Tarde o Temprano - Instrumental
# 	 Cárcel de Cristal - Instrumental
# 	 En Este Bar - Instrumental
# 	 Alza Tus Manos (Atlántico Remix) - Instrumental
# 	 1 de Diciembre - Instrumental
# 	 Pido Perdón - Instrumental
# 	 De Vuelta de Nada - Instrumental
# 	 Prejuicios - Instrumental
# 	 Tipos Normales - Instrumental
# Más Fuego Instrumentales:
# 	 Más Fuego - Instrumental
# 	 La Cabra Tira al Monte - Intrumental
# 	 Salto al Vacío - Instrumental
# 	 Padre Nuestro - Instrumental
# 	 Putos - Instrumental
# 	 Sangre en la Arena - Instrumental
# 	 En Tu Propia Bilis - Instrumental
# 	 Sin Tiempo - Instrumental
# 	 Surco las Estrellas - Instrumental
# 	 La Senda - Instrumental
# Atlántico:
# 	 Un Día Especial
# 	 Sigo Vivo
# 	 El Túnel
# 	 Tarde o Temprano
# 	 Cárcel de Cristal
# 	 En Este Bar
# 	 Alza Tus Manos Atlántico Remix - Atlántico Remix
# 	 1 de Diciembre
# 	 Pido Perdón
# 	 De Vuelta de Nada
# 	 Prejuicios
# Ave Fénix Instrumentales:
# 	 Despega - Instrumental
# 	 La Leyenda del Fénix - Instrumental
# 	 Nos Veremos - Instrumental
# 	 Explosión - Instrumental
# 	 Gorda - Instrumental
# 	 Que Vergüenza, Mamá - Instrumental
# 	 Déjame en Paz - Instrumental
# 	 Las Dos Caras - Instrumental
# 	 Buscarruínas - Instrumental
# 	 Criaturas de la Noche - Instrumental
# 	 Street Fighter - Instrumental
# 	 Hala Madrid - Instrumental
# 	 Enséñame la Pasta - Instrumental
# 	 Jura por Tu Dios - Instrumental
# 	 La Locura Está en Mi Remix - Remix Instrumental
# 	 Segundos Fuera - Instrumental
# Mas Fuego:
# 	 Más Fuego
# 	 La Cabra Tira Al Monte
# 	 Salto Al Vacío (Con Aitor Y Norykko)
# 	 Padre Nuestro
# 	 Putos (Con Aitor, Elley, Sony Y Medikoskil)
# 	 Sangre En La Arena
# 	 En Tu Propia Bilis
# 	 Sin Tiempo (Con Norykko)
# 	 Surco Las Estrellas
# 	 La Senda
# Ave Fénix:
# 	 Despega (feat. Eneyser & Norykko)
# 	 La Leyenda del Fénix
# 	 Nos Veremos
# 	 Explosión (feat. Norykko)
# 	 Gorda
# 	 Qué Vergüenza, Mamá
# 	 Déjame en Paz (feat. Dani Reus)
# 	 Las Dos Caras (feat. Eneyser)
# 	 Buscarruinas
# 	 Criaturas de la Noche
# 	 Street Fighter
# 	 Hala Madrid
# 	 Enséñame la Pasta - Remix
# 	 Jura por Tu Dios
# 	 La Locura Está en Mí (feat. Porta & Eneyser) - Remix
# 	 Segundos Fuera (feat. Encyser, Kurricé, Porta & Norykko)
# Desterrados:
# 	 Arriba las Manos
# 	 El "Emsí" con Más Sabor
# 	 ¡Que la Fuerza te Acompañe!
# 	 Los M.C.'s También Lloran
# 	 Acorralado sin Salida
# 	 Regalitos para Todos
# 	 Victoria
# 	 Aquel Chico
# 	 ¿Quién se pudo Comparar?
# 	 La Profecía
# Regalitos:
# 	 Regalitos
# 	 Regalitos - Instrumental
# Latin Girls (Remix):
# 	 Latin Girls - Remix
# Aún Hay Luz:
# 	 Aún Hay Luz
# El Artesano:
# 	 El Artesano
# 	 El artesano - Instrumental
# Nacidos para Ganar:
# 	 Nacidos para Ganar
# 	 Nacidos para ganar - Instrumental
# Facha:
# 	 Facha
# 	 Facha - Instrumental
# Protocolo Misántropo:
# 	 Protocolo Misántropo
# 	 Protocolo misántropo - Instrumental
# Viento y Marea:
# 	 Viento y Marea
# 	 Viento y marea - Instrumental
# Violencia:
# 	 Violencia
# 	 Violencia - Instrumental
# Hienas:
# 	 Hienas
# 	 Hienas - Instrumental
# México Tour 2018:
# 	 México Tour 2018
# 	 México Tour 2018 - Instrumental
# Méritos Propios:
# 	 Méritos Propios
# 	 Méritos Propios - Instrumental
# Tóxico Destino:
# 	 Tóxico Destino
# 	 Tóxico Destino - Instrumental
# Horror y Fe:
# 	 Horror y Fe
# 	 Horror y Fe - Instrumental
# Tu Voluntad:
# 	 Tu Voluntad
# 	 Tu Voluntad - Instrumental
# No Hay 2 Sin 3:
# 	 No Hay 2 Sin 3
# 	 No Hay 2 Sin 3 - Instrumental
# Héroes:
# 	 Héroes
# 	 Héroes - Instrumental
# Hasta Que Amanezca:
# 	 Hasta Que Amanezca
# 	 Hasta Que Amanezca - Instrumental
# No Hay Vuelta Atrás:
# 	 No Hay Vuelta Atrás
# 	 No Hay Vuelta Atrás - Instrumental
# Menuda Fiesta:
# 	 Menuda Fiesta
# 	 Menuda Fiesta - Instrumental
# La Resistencia:
# 	 La Resistencia
# 	 La Resistencia - Instrumental
# Nana al Decadente:
# 	 Nana al Decadente
# 	 Nana al Decadente
# 	 Nana al Decadente - Instrumental
# Rap de Spiderman:
# 	 Rap de Spiderman
# 	 Rap de Spiderman - Instrumental
# Rap de Prison Break:
# 	 Rap de Prison Break
# 	 Rap de Prison Break - Instrumental
# Rap de Wonder Woman:
# 	 Rap De Wonder Woman
# 	 Rap de Wonder Woman - Instrumental
# Rap de Alien:
# 	 Rap de Alien
# 	 Rap de Alein - Instrumental
# Rap de Rocky:
# 	 Rap de Rocky
# 	 Rap de Rocky - Instrumental
# Rap de Rápidos y Furiosos:
# 	 Rap de Rápidos y Furiosos
# 	 Rap de Rápidos y Furiosos - Instrumental
# Rap de Piratas del Caribe:
# 	 Rap de Piratas del Caribe
# 	 Rap de Piratas del Caribe - Instrumental
# Rap De: Por 13 Razones:
# 	 Rap De: Por 13 Razones
# 	 Rap De: Por 13 Razones - Instrumental
# Guardianes de la Moral:
# 	 Guardianes de la Moral
# 	 Guardianes de la Moral - Instrumental
# Rap de Scream:
# 	 Rap de Scream
# 	 Rap de Scream - Instrumental
# Mala Suerte:
# 	 Mala Suerte
# 	 Mala Suerte - Instrumental
# Brusgüein:
# 	 Brusgüein
# 	 Brusgüein - Instrumental
# Feminazis:
# 	 Feminazis
# 	 Feminazis - Instrumental
# A Nuestra Merced:
# 	 A Nuestra Merced
# 	 A Nuestra Merced - Instrumental
# Roast Yourself:
# 	 Roast Yourself
# 	 Roast Yourself - Instrumental
# Antihéroes:
# 	 Antihéroes
# 	 Antihéroes - Instrumental
# Bang Bang:
# 	 Bang Bang
# 	 Bang Bang - Instrumental
# Prólogo:
# 	 Prólogo
# 	 Prólogo - Instrumental
# Tu Sabor:
# 	 Tu Sabor
# 	 Tu Sabor - Instrumental
# Sin Más Motivos:
# 	 Sin Más Motivos
# 	 Sin Más Motivos - Instrumental
# Mierda en Hd:
# 	 Mierda en Hd
# 	 Mierda en Hd - Instrumental
# Mi Energía (feat. Aitor):
# 	 Mi Energía
# 	 Mi Energía - Instrumental
# Las Llamas de la Verdad:
# 	 Las Llamas de la Verdad
# 	 Las Llamas de la Verdad - Instrumental
# Villancico Rap:
# 	 Villancico Rap
# 	 Villnacico Rap - Instrumental
# Sin Tregua:
# 	 Sin Tregua
# 	 Sin Tregua - Instrumental
# Guerra de Clanes:
# 	 Guerra de Clanes
# 	 Guerra de Clanes - Instrumental
# Tanto Que Aprender:
# 	 Tanto Que Aprender
# 	 Tanto Que Aprender - Instrumental
# Next Level Remix:
# 	 Next Level - Remix
# 	 Next Level - Remix Instrumental
# Sin Miedo a Caer (Remix):
# 	 Sin Miedo a Caer (Remix)
# 	 Sin Miedo a Caer (Remix) - Instrumental
# Avalancha Magnos - EP:
# 	 Rock This Club
# 	 Héroe
# 	 La Cabra Tira al Monte
# 	 Segundos Fuera Remix
# Niño Grande:
# 	 Niño Grande
# 	 Niño grande - Instrumental
# Level 2:
# 	 Intro Level 2
# 	 No Se Rinde
# 	 Mr. Psycho III
# 	 Blanco y Negro
# 	 No Pediré Perdón
# 	 Mi Lista
# 	 Intro Level 2 - Instrumental
# 	 No se rinde - Instrumental
# 	 Mr. Psycho III - Instrumental
# 	 Blanco y negro - Instrumental
# 	 No pediré perdón - Instrumental
# 	 Mi lista - Instrumental
# No Pediré Perdón:
# 	 No Pediré Perdón
# 	 No pediré perdón - Instrumental
# No Se Rinde:
# 	 No Se Rinde
# 	 No se rinde - Instrumental
# Fiesta Privada:
# 	 Soy un Desastre
# 	 Loco
# 	 Sigo Aquí
# 	 Quieres Creer
# 	 Los Dos
# 	 Remordimientos
# 	 Boss
# 	 La Sal en la Herida
# 	 Mi Contradicción
# 	 Cada Vez
# 	 Corre
# Soy un Desastre:
# 	 Soy un Desastre
# 	 Soy un Desastre - Instrumental
# Remordimientos:
# 	 Remordimientos
# 	 Remordimientos - Instrumental
# Bajo Cero:
# 	 Bajo Zero
# 	 En Este Track
# 	 Conquístame
# 	 Reguestyla
# 	 Killers
# 	 Canción para Mí
# 	 Rap en la Sangre
# 	 6 Letras
# 	 Tu Adiós
# 	 Corre, Grita, Llora
# 	 Por Qué
# 	 Interludio Presentando Silhaz
# 	 Kobra
# 	 Manos al Cielo
# 	 3, 2, 1
# 	 Intento
# 	 Más Allá de Tu Ventana
# 	 Aunque Les Duela
# 	 No Pasa Nada
# Buscar Culpables:
# 	 Buscar Culpables
# 	 Buscar Culpables - Instrumental
# Diamante en Bruto:
# 	 Empieza el Juego
# 	 Diamante en Bruto
# 	 Desde Dentro
# 	 Mi Voz Sonará
# 	 Mi Diamante
# 	 Lo Que Pueda Venir
# 	 Imagino
# 	 Estás Fuera
# 	 Lo Más Profundo
# 	 Ajuste de Cuentas
# Standard:
# 	 Esto Es Hip Hop
# 	 Ten Valor (feat. Santaflow)
# 	 Si Tú (feat. Fary)
# 	 Fiesta Underground (feat. Mr. Fer)
# 	 Nunca
# 	 Imagina
# 	 Tú y Yo (feat. Dani Toralla)
# 	 Dime
# 	 Fué (feat. Fary)
# Estás Fuera (feat. Aitor & Santaflow):
# 	 Estás Fuera
# 	 Estás Fuera - Instrumental
# Game Over:
# 	 Game Over
# 	 Next Level
# 	 Amor Sin Censura
# 	 Viviendo el Sueño
# 	 Latin Girls
# 	 Todo Es Mejor
# 	 Nos Vamos
# 	 El Lado Oscuro de la Fiesta
# 	 Noche de Brujas
# 	 Malas Intenciones
# 	 Vengo de la Calle
# 	 Su Recompensa
# 	 Fieras Nocturnas
# 	 Sandwich
# 	 Gracias
# 	 Chica de Pueblo
# Game Over (Parte 2):
# 	 Noche de Brujas
# 	 Malas Intenciones
# 	 Vengo de la Calle
# 	 Su Recompensa
# 	 Fieras Nocturnas
# 	 Sandwich
# 	 Gracias
# 	 Chica de Pueblo
# 	 Noche de brujas - Instrumental
# 	 Malas intenciones - instrumental
# 	 Vengo de la calle - Instrumental
# 	 Su recompensa - Instrumental
# 	 Fieras nocturnas - Instrumental
# 	 Sandwich - Instrumental
# 	 Gracias - Instrumental
# 	 Chica de Pueblo - Instrumental
# Empieza el Juego:
# 	 Empieza el Juego
# 	 Empieza el Juego - Instrumental
# Desde Dentro:
# 	 Desde Dentro
# 	 Desde Dentro - Instrumental
# Game Over (Parte 1):
# 	 Game Over
# 	 Next Level
# 	 Amor Sin Censura
# 	 Viviendo el Sueño
# 	 Latin Girls
# 	 Todo Es Mejor
# 	 Nos Vamos
# 	 El Lado Oscuro de la Fiesta
# 	 Game Over - Instrumental
# 	 Next Level - Instrumental
# 	 Amor Sin Censura - Instrumental
# 	 Viviendo el Sueño - Instrumental
# 	 Latin Girls - Instrumental
# 	 Todo Es Mejor - Instrumental
# 	 Nos Vamos - Instrumental
# 	 El Lado Oscuro de la Fiesta - Instrumental
# Subliminal:
# 	 Subliminal
# 	 En Tu Sien
# 	 Al Revés
# 	 Habitantes
# 	 Dejándote Seco
# 	 El Secreto
# 	 El Secreto - Remix
# 	 Subliminal - Instrumental
# 	 En Tu Sien - Instrumental
# 	 Al Revés - Instrumental
# 	 Habitantes - Instrumental
# 	 Dejándote Seco - Instrumental
# 	 El Secreto - Instrumental
# Chapter One:
# Error en request. {'error': {'status': 429, 'message': 'API rate limit exceeded'}}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-ac9e3cc38718> in <module>()
#       1 id_santaflow = '3uvTa6pDzj0T6EfMslXOCs'
# ----> 2 print_all_song_artist(id_santaflow, token)
#
# <ipython-input-63-04ac8a99f4d4> in print_all_song_artist(id_artist, token)
#       2   for album in get_discography(id_artist, token, return_name=True, country='CO'):
#       3     print(f'{album[1]}:')
# ----> 4     for track in get_tracks(album[0], token, return_name=True, market='CO'):
#       5       print(f'\t {track[1]}')
#
# TypeError: 'NoneType' object is not iterable

# %%
preview_url = 'https://p.scdn.co/mp3-preview/19f246884cb9470179c21d9fbdbcf1047ce2a3b2?cid=47edb8490fbe4f26b7d4023e86d43773'
preview = requests.get(preview_url)
preview
# Out:
# <Response [200]>

# %%
import IPython.display as ipd

# %%
ipd.Audio(preview.content)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
